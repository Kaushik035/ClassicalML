# %% [markdown]
# # Mutually Exclusive
#
# - In probability theory, two events are considered mutually exclusive if they cannot occur at the same time. This means that if one event happens, the other event cannot happen. For example, when flipping a coin, the events "heads" and "tails" are mutually exclusive because you cannot get both outcomes in a single flip.
#
# ![image.png](attachment:image.png)
