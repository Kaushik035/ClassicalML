# %% [markdown]
# # Naive Bayes Intuition
#
# ![image.png](attachment:image.png)
#
# - So Naive Bayes chooses the class with the highest posterior probability.
#
# - We want to predict when toss=loss,venue =Mumbai, outlook=overcast, whether the team will win or lose.
#
# - Notation:
#     - {Loss AND Mumbai AND Overcast} = {Loss, Mumbai, Overcast} = $X$
#
# ![image-2.png](attachment:image-2.png)
#
# - The end stratergy is to calculate $P(W \mid X)$ and $P(L \mid X)$ and compare them.
#
# - If you notice, that denominator is the same for both classes, so we can ignore it and just compare the numerators.
#
# ![image-3.png](attachment:image-3.png)
#
# - But in the above formula, we have $P(X \mid W)$ = 0
#
# - This is where the "Naive" assumption comes in. We assume that the features are conditionally independent given the class.
#
# - The problem was the term $P(X \mid W)$, which is the probability of observing the combination of features given that the class is "Won" is a very specific combination that we might not have seen in our training data.
#
# - By assuming independence, we can break down $P(X \mid W)$ into the product of the probabilities of each feature given the class:
#
# ![image-4.png](attachment:image-4.png)
