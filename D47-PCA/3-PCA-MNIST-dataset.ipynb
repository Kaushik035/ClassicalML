# %% [markdown]
# ![image.png](attachment:image.png)
#
# - MNIST is a dataset of handwritten digits, where each image is represented as a 784-dimensional vector (28x28 pixels).
# - Target: we need to classify the digits (0-9) based on these high-dimensional vectors.
# - First we will do without PCA and then with PCA to see the difference.

# %% [markdown]
# PCA code Kaggle notebook :
# - https://www.kaggle.com/nitsin/pca-demo-1
# - https://www.kaggle.com/code/kaushik035/pca-demo/edit

# %% [markdown]
# # Finding Optimimal no. of Principal Components to take:
#
# ![image.png](attachment:image.png)
# - Each eigenvalue represents the amount of variance captured by its corresponding eigenvector (principal component) but its not percentage variance captured.
# ### <span style="color:orange">So, we have to take the top k eigenvectors that capture the 90% variance in the data.</span>
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### See the pca-demo.ipynb or kaggle link for the code and visualization of PCA on MNIST dataset.
