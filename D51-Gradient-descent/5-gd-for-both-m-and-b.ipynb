# %% [markdown]
# # Now, we will see how to calculate both m and b using GD
#
# - **Step 1:**  Initialize $m$ and $b$ with some random values ($m$ = 1 and $b$ = 0)
#
# - **Step 2:**  Decide number of epochs and learning rate ( $epochs$ = 100 and $learning\_rate$ = 0.01)
#
# - **Step 3:**  Write the loop for updating $m$ and $b$ using the following formulas:
#
#     ![image.png](attachment:image.png)
#
#     - For b, we know the expression of slope
#
#     - Similarly for m, we need to find the expression of slope, we can do that by taking the partial derivative of the cost function with respect to m
#
#     ![image-4.png](attachment:image-4.png)
#
#     ![image-5.png](attachment:image-5.png)
#
#     - So earlier the cost function was 2D parabolic function, now it will be 3D paraboloid function because we have two parameters m and b (see below the notebool the cost function is plotted in 3D)
#
#     ![image-2.png](attachment:image-2.png)
#
#     ![image-3.png](attachment:image-3.png)
#
#     - guess aap kahi se vhi le skte ho, pr at the end motive hai to down the slope to get the minimum value of the loss (cost) function
#
# - So now the L(m,b) is a function of multipe (here two) variables, that's why its slope is known as gradient
#
# - And we need to find slope in the direction of all the variables (here m and b), and their combination tells us ki minimum value of the cost function kaha hoga, and that is the point where the gradient is zero
#
# - For now we are just focusing on 2-dimensional case, later we will deal with more input fratures, so there will be more parameters to optimize

# %% [markdown]
# Let's edit the class we created earlier to include the calculation of both m and b using GD, see the next file.

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1,noise=20,random_state=13)

# %%
plt.scatter(X,y)

# %%
m_arr = np.linspace(-150, 150, 10)
b_arr = np.linspace(-150, 150, 10)
mGrid, bGrid = np.meshgrid(m_arr,b_arr)

final = np.vstack((mGrid.ravel().reshape(1,100),bGrid.ravel().reshape(1,100))).T

z_arr = []

for i in range(final.shape[0]):
    z_arr.append(np.sum((y - final[i,0]*X.reshape(100) - final[i,1])**2))

z_arr = np.array(z_arr).reshape(10,10)

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Surface(x = m_arr, y = b_arr, z =z_arr)])

fig.update_layout(title='Cost Function', autosize=False,
                  width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90))



fig.show()

fig.write_html("cost_function.html")

# x is m and y is b, z is cost

# %%
b = 150
m = -127.82
lr = 0.001
all_b = []
all_m = []
all_cost = []

epochs = 30

for i in range(epochs):
    slope_b = 0
    slope_m = 0
    cost = 0
    for j in range(X.shape[0]):
        slope_b = slope_b - 2*(y[j] - (m * X[j]) -  b)
        slope_m = slope_m - 2*(y[j] - (m * X[j]) -  b)*X[j]
        cost = cost + (y[j] - m * X[j] -b) ** 2

    b = b - (lr * slope_b)
    m = m - (lr * slope_m)
    all_b.append(b)
    all_m.append(m)
    all_cost.append(cost)

# %%
import plotly.express as px

fig = px.scatter_3d(x=np.array(all_m).ravel(), y=np.array(all_b).ravel(), z=np.array(all_cost).ravel()*100)

fig.add_trace(go.Surface(x = m_arr, y = b_arr, z =z_arr*100 ))

fig.show()

fig.write_html("cost_function2.html")

# %%
import plotly.graph_objects as go

fig = go.Figure(go.Scatter(x=np.array(all_m).ravel(), y=np.array(all_b).ravel(), name='High 2014',
                         line=dict(color='#fff', width=4)))

fig.add_trace(go.Contour(z=z_arr,x=m_arr,y=b_arr))
fig.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


fig,ax=plt.subplots(1,1)
plt.figure(figsize=(18,4))
cp = ax.contourf(m_arr, b_arr, z_arr)
ax.plot(np.array(all_m).ravel(),np.array(all_b).ravel(),color='white')
fig.colorbar(cp) # Add a colorbar to a plot
ax.set_title('Filled Contours Plot')
ax.set_xlabel('m')
ax.set_ylabel('b')
plt.show()

# %%
# %matplotlib notebook
from matplotlib.animation import FuncAnimation
import matplotlib.animation as animation

# intercept graph
num_epochs = list(range(0,30))
fig = plt.figure(figsize=(9,5)) 
axis = plt.axes(xlim =(-150, 150), ylim =(-150, 150)) 

axis.contourf(m_arr, b_arr, z_arr)

line, = axis.plot([], [], lw = 2,color='white') 
  
xdata, ydata = [], [] 
  
# animation function 
def animate(i): 
    label = 'epoch {0}'.format(i + 1)
    xdata.append(all_m[i]) 
    ydata.append(all_b[i]) 
    line.set_data(xdata, ydata) 
    axis.set_xlabel(label)
      
    return line, 
  
# calling the animation function     
anim = animation.FuncAnimation(fig, animate, frames = 30,repeat=False, interval = 500)

#f = r"animation8.gif" 
#writergif = animation.PillowWriter(fps=2) 
#anim.save(f, writer=writergif)
# Out:
# <div id='22a60086-d5db-49f7-b2a6-308fc7af5246'></div>
