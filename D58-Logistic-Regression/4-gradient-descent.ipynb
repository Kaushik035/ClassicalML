# %% [markdown]
# # Derivative of Sigmoid Function
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Gradient Descent for Logistic Regression
#
# ![image.png](attachment:image.png)
#
# - Calculate the $\hat{y_i}$ for each data point (each row of $X$)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
#
# # Loss Function for Logistic Regression in matrix form:
#
# ![image-7.png](attachment:image-7.png)
#
# ![image-8.png](attachment:image-8.png)
#
# ![image-9.png](attachment:image-9.png)
#
# ![image-10.png](attachment:image-10.png)
#
# Simillarly the 2nd term can be written as:
#
# ![image-11.png](attachment:image-11.png)
#
# - so the final loss function can be written as:
#
# ![image-12.png](attachment:image-12.png)
#
# - where $m$ is the number of rows in $X$ (number of data points)
#
# - #### As there is no closed solution for minimizing the loss function, we will use gradient descent to minimize it. And find the value of $W$ that minimizes the loss function.

# %% [markdown]
# # Applying Gradient Descent to Logistic Regression
#
# ![image.png](attachment:image.png)
#
# - #### How to calculate $\frac{\partial L}{\partial W}$?
#
# - Differentiation of the first term:
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# - Differentiation of the second term:
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# - So the final gradient of the loss function can be written as:
#
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)
#
# ## So, the update rule for gradient descent can be written as:
#
# ![image-8.png](attachment:image-8.png)
# ![image-9.png](attachment:image-9.png)
#
# - Now we just need to code the above update rule in a loop until convergence to find the optimal value of $W$ that minimizes the loss function.

# %%
from sklearn.datasets import make_classification
import numpy as np
X, y = make_classification(n_samples=100, n_features=2, n_informative=1,n_redundant=0,
                           n_classes=2, n_clusters_per_class=1, random_state=41,hypercube=False,class_sep=20)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)

# %%
from sklearn.linear_model import LogisticRegression

lor = LogisticRegression(penalty=None, solver='sag', max_iter=1000)
# we set the penalty to None to avoid regularization as our implementation doesn't have regularization, and we set the solver to 'sag' which is a fast solver for large datasets, and we set the max_iter to 1000 to ensure convergence
lor.fit(X, y)
# Out:
# c:\Users\Kaushik Mandal\.virtualenvs\ClassicalML-_wR1sNSC\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# LogisticRegression(max_iter=1000, penalty=None, solver='sag')

# %%
print(lor.coef_)
print(lor.intercept_)
# Out:
# [[4.96238317 0.29454808]]
# [4.93512207]

# %%
m1 = -(lor.coef_[0][0]/lor.coef_[0][1])
b1 = -(lor.intercept_/lor.coef_[0][1])

# %%
x_input = np.linspace(-3,3,100)
y_input = m1*x_input + b1

# %%
def gd(X,y):
    
    X = np.insert(X,0,1,axis=1)
    weights = np.ones(X.shape[1])
    lr = 0.5
    epochs = 1000
    for i in range(epochs):
        y_hat = sigmoid(np.dot(X,weights))
        weights = weights + lr*(np.dot((y-y_hat),X)/X.shape[0])
        
    return weights[1:],weights[0]

# %%
def sigmoid(z):
    return 1/(1 + np.exp(-z))

# %%
coef_,intercept_ = gd(X,y)

# %%
m = -(coef_[0]/coef_[1])
b = -(intercept_/coef_[1])

# %%
x_input1 = np.linspace(-3,3,100)
y_input1 = m*x_input1 + b

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color='red',linewidth=3) # sklearn
plt.plot(x_input1,y_input1,color='black',linewidth=3) # gradient descent our implementation
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)

# %% [markdown]
# - You can see, that our implementation is almost close (if we tune the learning rate and the number of epochs) to the line we got from sklearn's implementation of logistic regression.
#
# - Here we used Batch Gradient Descent, where we calculate the gradient using all the data points in each iteration. We can also use Stochastic Gradient Descent (SGD) or Mini-batch Gradient Descent
